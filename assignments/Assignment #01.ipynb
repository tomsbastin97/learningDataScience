# %% [markdown]
# # Assignment #01 - Python for Data Science

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/tomsbastin97/anaconda3/lib/python3.8/site-packages')
import seaborn as sns

# %% [markdown]
# ### 1. Read the dataset to python environment.

# %%
dataset = pd.read_excel('iris.xls')

# %% [markdown]
# ### 2. Display the columns in the dataset.

# %%
dataset
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 3. Calculate the mean of each column of the dataset.

# %%
np.mean(dataset, axis=0)
# Out:
# /home/tomsbastin97/.local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3438: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ### 4.Check for the null values present in the dataset.

# %%
print(dataset.isnull().any())
print(dataset.isnull().sum())
# Out:
# SL                False
# SW                False
# PL                False
# PW                False
# Classification    False
# dtype: bool
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ### 5.Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
iris_setosa = (dataset[dataset.Classification.str.contains('iris-setosa', case = False)])
iris_virginica = (dataset[dataset.Classification.str.contains('iris-virginica', case = False)])
iris_versicolor = (dataset[dataset.Classification.str.contains('iris-versicolor', case = False)])
print(dataset['Classification'].value_counts())

plt.figure()
plt.title('Petal Length vs Petal Width')
sns.scatterplot(dataset['PL'], dataset['PW'], hue= dataset['Classification'], s = 50)
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')


plt.figure()
plt.title('Sepal Length vs Sepal Width')
sns.scatterplot(dataset['SL'], dataset['SW'], hue= dataset['Classification'], s = 50)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')

plt.figure(figsize=(7,8))
plt.title('Heatmap to show correlation')
sns.heatmap(dataset.corr(),annot=True)
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Classification, dtype: int64
# /home/tomsbastin97/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/tomsbastin97/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Heatmap to show correlation'}>
